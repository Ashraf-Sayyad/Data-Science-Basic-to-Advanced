# %%
from scipy import stats
import pandas as pd
import numpy as np

# %%
glaxo_df=pd.read_csv('/content/glaxo_df.csv')
glaxo_df
# Out:
#             Date    Close      gain
# 0     05-01-2010  1616.80 -0.005444
# 1     06-01-2010  1638.50  0.013422
# 2     07-01-2010  1648.70  0.006225
# 3     08-01-2010  1639.80 -0.005398
# 4     11-01-2010  1629.45 -0.006312
# ...          ...      ...       ...
# 1733  26-12-2016  2723.50 -0.001283
# 1734  27-12-2016  2701.75 -0.007986
# 1735  28-12-2016  2702.15  0.000148
# 1736  29-12-2016  2727.90  0.009529
# 1737  30-12-2016  2729.80  0.000697
#
# [1738 rows x 3 columns]

# %% [markdown]
# # **Confidence Interval using Normal Distribution - Z Distribution, Sigma Known**

# %%
#Find confidence interval first using normal distribution
# here stats.norm.interval() will give you directly conf.interval for 95 % confidence. No need to do other calculations.
glaxo_df_ci = stats.norm.interval(0.95,loc = glaxo_df.gain.mean(),
                                  scale = glaxo_df.gain.std())
print(glaxo_df_ci)
print( 'Mean at 95% confidence interval is:', np.round(glaxo_df_ci, 4))
#For Glaxo max profit or loss can be expected in between -2.5% to 2.6% on a particular day.
# Out:
# (np.float64(-0.025800133344318268), np.float64(0.02657221539610193))
# Mean at 95% confidence interval is: [-0.0258  0.0266]

# %%
glaxo_df_ci
# Out:
# (np.float64(-0.025800133344318268), np.float64(0.02657221539610193))

# %%
beml_df=pd.read_csv('/content/beml_df.csv')
beml_df
# Out:
#             Date    Close      gain
# 0     05-01-2010  1134.60 -0.000881
# 1     06-01-2010  1139.60  0.004407
# 2     07-01-2010  1144.15  0.003993
# 3     08-01-2010  1144.05 -0.000087
# 4     11-01-2010  1137.00 -0.006162
# ...          ...      ...       ...
# 1733  26-12-2016   950.25 -0.021924
# 1734  27-12-2016   975.70  0.026782
# 1735  28-12-2016   974.40 -0.001332
# 1736  29-12-2016   986.05  0.011956
# 1737  30-12-2016  1000.60  0.014756
#
# [1738 rows x 3 columns]

# %%
beml_df_ci=stats.norm.interval(0.95,loc = beml_df.gain.mean(),scale = beml_df.gain.std())
print( 'Mean at 95% confidence interval is:', np.round(beml_df_ci, 4))
#For BEML max profit or loss can be expected in between -5.1% to 5.2% in a particular day.
# Out:
# Mean at 95% confidence interval is: [-0.0515  0.0521]

# %%
# Credit card example - University xbar=1990,n=140,population std dev sigma=2500
std_error=2500/np.sqrt(140)
ci=stats.norm.interval(0.95,1990,std_error)
ci
# Out:
# (np.float64(1575.8820248378292), np.float64(2404.1179751621708))

# %%
beml_df_ci
# Out:
# (np.float64(-0.05153272969195403), np.float64(0.05207422584385276))

# %%
glaxo_df
# Out:
#             Date    Close      gain
# 0     05-01-2010  1616.80 -0.005444
# 1     06-01-2010  1638.50  0.013422
# 2     07-01-2010  1648.70  0.006225
# 3     08-01-2010  1639.80 -0.005398
# 4     11-01-2010  1629.45 -0.006312
# ...          ...      ...       ...
# 1733  26-12-2016  2723.50 -0.001283
# 1734  27-12-2016  2701.75 -0.007986
# 1735  28-12-2016  2702.15  0.000148
# 1736  29-12-2016  2727.90  0.009529
# 1737  30-12-2016  2729.80  0.000697
#
# [1738 rows x 3 columns]

# %% [markdown]
# # **Confidence interval using t-distribution (Sigma Unknown)**

# %%
glaxo_df_ci=stats.t.interval(0.95,1737,
                             loc = glaxo_df.gain.mean(),
                             scale = glaxo_df.gain.std())
glaxo_df_ci #0.95 - confidence, 1737 - degrees of freedom, loc - mean, scale - std deviation
# Out:
# (np.float64(-0.025818392723964804), np.float64(0.026590474775748465))

# %%
beml_df_ci=stats.t.interval(0.95,1737,
                             loc = beml_df.gain.mean(),
                             scale = beml_df.gain.std())
beml_df_ci #0.95 - confidence, 1737 - degrees of freedom (n-1), loc - mean, scale - std deviation
# Out:
# (np.float64(-0.05156885178272614), np.float64(0.05211034793462487))

# %%
beml_df.gain.mean()
# Out:
# np.float64(0.00027074807594936704)

# %%
beml_df.gain.std()
# Out:
# 0.026430831472681448

# %%
#Find confidence interval using t distribution - Credit card example
#stats.t.ppf(0.975,139) # t value for 95% confidence
stats.t.ppf(0.95,139) # t value for 90% confidence.t.ppf(0.95
# Out:
# np.float64(1.6558898677725957)
